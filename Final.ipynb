# %%
import numpy as np
import threading
from threading import Thread
import pandas as pd
import re
import nltk
import spacy
import string
import queue
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import linear_kernel,cosine_similarity
from sklearn.decomposition import TruncatedSVD
from io import StringIO
from nltk.corpus import stopwords
from collections import Counter
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
import time
from collections import Counter
from subprocess import call

# %% [markdown]
# # READ DATA

# %%
df112 = pd.read_csv('1 Billion Citation Dataset, v1 (112).csv') 
df109 = pd.read_csv('1 Billion Citation Dataset, v1 (109).csv')

# %% [markdown]
# # SPLIT DATA

# %%
# Split data 112
d1f12 = df112[:200000]
d2f12 = df112[200000:400000]
d3f12 = df112[400000:600000]
d4f12 = df112[600000:800000]
d5f12 = df112[800000:1000000]
d6f12 = df112[1000000:1200000]
d7f12 = df112[1200000:1400000]
# d8f12 = df112[1400000:1600000]
# d9f12 = df112[1600000:1800000]
# d0f12 = df112[1800000:2000000]

# %%
# Split data 109
d1f09 = df109[:200000]
d2f09 = df109[200000:400000]
d3f09 = df109[400000:600000]
d4f09 = df109[600000:800000]
d5f09 = df109[800000:1000000]
d6f09 = df109[1000000:1200000]
d7f09 = df109[1200000:1400000]
# d8f09 = df109[1400000:1600000]
# d9f09 = df109[1600000:1800000]
# d0f09 = df109[1800000:2000000]

# %% [markdown]
# # PREPROCESS

# %%
def remove_urls(text):
  url_pattern = re.compile(r"https?://\S+|www\.\S+")
  return url_pattern.sub(r"", text)

def remove_html(text):
  html_pattern = re.compile("<.*?>")
  return html_pattern.sub(r"", text)

PUNCT = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","" , PUNCT))

PUNCT = string.punctuation
def remove_punctuation(text):
    return text.translate(str.maketrans("","" , PUNCT))

nltk.download('stopwords')
",".join(stopwords.words("english"))
STOPW = set(stopwords.words("english"),)
def remove_stopwords(text):
  return" ".join([word for word in str(text).split() if word not in STOPW])
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Admins\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
def preprocess(df):
    # Convert_lowerCase(df, "citationStringAnnotated")
    # df["Preprocess"] = df["citationStringAnnotated"].apply(lambda text: stem_words(text))
    # df["Preprocess"] = df["Preprocess"].apply(lambda text: lemmatize_words(text))
    df_preprocess = df.loc[:,'citationStringAnnotated']
    df_preprocess = df_preprocess.astype(str)
    df_preprocess = df_preprocess.str.lower()
    df_preprocess = df_preprocess.apply(lambda text: remove_urls(text))
    df_preprocess = df_preprocess.apply(lambda text: remove_html(text))
    df_preprocess= df_preprocess.apply(lambda text: remove_punctuation(text))
    df_preprocess = df_preprocess.apply(lambda text: remove_stopwords(text))
    df_preprocess = df_preprocess.str.replace('\d+', '',regex=True)

    return df_preprocess

# %%
class ThreadWithReturnValue(Thread):
    def __init__(self, group=None, target=None, name=None,
                 args=(), kwargs={}, Verbose=None):
        Thread.__init__(self, group, target, name, args, kwargs)
        self._return = None
    def run(self):
        print(type(self._target))
        if self._target is not None:
            self._return = self._target(*self._args,
                                                **self._kwargs)
    def join(self, *args):
        Thread.join(self, *args)
        return self._return

# %% [markdown]
# # MULTITHREADING PREPROCESS FOR CSV112

# %%
thread1 = ThreadWithReturnValue(target = preprocess, args=(d1f12,))
thread2 = ThreadWithReturnValue(target = preprocess, args=(d2f12,))
thread3 = ThreadWithReturnValue(target = preprocess, args=(d3f12,))
thread4 = ThreadWithReturnValue(target = preprocess, args=(d4f12,))
thread5 = ThreadWithReturnValue(target = preprocess, args=(d5f12,))
thread6 = ThreadWithReturnValue(target = preprocess, args=(d6f12,))
thread7 = ThreadWithReturnValue(target = preprocess, args=(d7f12,))
# thread8 = ThreadWithReturnValue(target = preprocess, args=(d8f12,))
# thread9 = ThreadWithReturnValue(target = preprocess, args=(d9f12,))
# thread0 = ThreadWithReturnValue(target = preprocess, args=(d0f12,))

thread1.start()
thread2.start()
thread3.start()
thread4.start()
thread5.start()
thread6.start()
thread7.start()
# thread8.start()
# thread9.start()
# thread0.start()

d1f12 = thread1.join()
d2f12 = thread2.join()
d3f12 = thread3.join()
d4f12 = thread4.join()
d5f12 = thread5.join()
d6f12 = thread6.join()
d7f12 = thread7.join()
# d8f12 = thread8.join()
# d9f12 = thread9.join()
# d0f12 = thread0.join()
# Out:
# <class 'function'>
# <class 'function'><class 'function'>
#
# <class 'function'>
# <class 'function'>
# <class 'function'>
# <class 'function'>

# %% [markdown]
# # MULTITHREADING PREPROCESS FOR CSV109

# %%
thread1 = ThreadWithReturnValue(target = preprocess, args=(d1f09,))
thread2 = ThreadWithReturnValue(target = preprocess, args=(d2f09,))
thread3 = ThreadWithReturnValue(target = preprocess, args=(d3f09,))
thread4 = ThreadWithReturnValue(target = preprocess, args=(d4f09,))
thread5 = ThreadWithReturnValue(target = preprocess, args=(d5f09,))
thread6 = ThreadWithReturnValue(target = preprocess, args=(d6f09,))
thread7 = ThreadWithReturnValue(target = preprocess, args=(d7f09,))
# thread8 = ThreadWithReturnValue(target = preprocess, args=(d8f09,))
# thread9 = ThreadWithReturnValue(target = preprocess, args=(d9f09,))
# thread0 = ThreadWithReturnValue(target = preprocess, args=(d0f09,))

thread1.start()
thread2.start()
thread3.start()
thread4.start()
thread5.start()
thread6.start()
thread7.start()
# thread8.start()
# thread9.start()
# thread0.start()

d1f09 = thread1.join()
d2f09 = thread2.join()
d3f09 = thread3.join()
d4f09 = thread4.join()
d5f09 = thread5.join()
d6f09 = thread6.join()
d7f09 = thread7.join()
# d8f09 = thread8.join()
# d9f09 = thread9.join()
# d0f09 = thread0.join()
# Out:
# <class 'function'>
# <class 'function'>
# <class 'function'>
# <class 'function'>
# <class 'function'>
# <class 'function'>
# <class 'function'>

# %% [markdown]
# # COMBINE DATA

# %%
# 112
frames_112 = [d1f12, d2f12, d3f12, d4f12, d5f12, d6f12, d7f12]
  
result_112 = pd.concat(frames_112)
display(result_112)
# Out:
# 0          yorizane masahiro sadarmoto shoozo yoshimura s...
# 1          anon  “chapter  frequencydomain behavior elect...
# 2          huang ximing chen jingchao fang xiaotong yan c...
# 3          demars b l harper pitt ja slaughter r  “impact...
# 4          ling jian ming zhu li guo yuan jie chai zhen l...
#                                  ...
# 1399995    rand jic law industrial relations relations in...
# 1399996    fu tc academic libraries hightech gateways gui...
# 1399997    bolonkin science soul paradise artificial inte...
# 1399998    chapter  climate changes solar system solar pl...
# 1399999    sauerland evidencebased medicine mean wound ca...
# Name: citationStringAnnotated, Length: 1400000, dtype: object

# %%
# 109
frames_109 = [d1f09, d2f09, d3f09, d4f09, d5f09, d6f09, d7f09]
  
result_109 = pd.concat(frames_109)
display(result_109)
# Out:
# 0          leder lukas llera andrea lavoie pascal lebedev...
# 1          golub v b popov yu  “a new lace bug species ge...
# 2          anon  “a study thyroid cancers detected ultras...
# 3          field tiffany greenberg reena  “temperament ra...
# 4          klingler  “angiographische messung der carotis...
#                                  ...
# 1399995    smith aw book reviews leslie sklair sociology ...
# 1399996    correction genetic predisposition high blood p...
# 1399997    bresnahan r freire la chilena latin american p...
# 1399998    freud brill aa dream fulfilment wish interpret...
# 1399999    wang r liu jiang et al passively qswitched mod...
# Name: citationStringAnnotated, Length: 1400000, dtype: object

# %% [markdown]
# # BUILD LSA

# %%
def build_lsa(dataset, dim, queue ):
        tfidf_vec = TfidfVectorizer(use_idf=True, norm='l2')
        svd = TruncatedSVD(n_components=dim)
    
        transformed_x_train = tfidf_vec.fit_transform(dataset)
    
        print('TF-IDF output shape:', transformed_x_train.shape)
    
        data_svd = svd.fit_transform(transformed_x_train)
    
        print('LSA output shape:', data_svd.shape)
    
        explained_variance = svd.explained_variance_ratio_.sum()
        print("Sum of explained variance ratio: %d%%" % (int(explained_variance * 100)))

        queue.put((tfidf_vec, transformed_x_train,svd, data_svd))

# %%
queue1 = queue.Queue()
queue2 = queue.Queue()
thread_lsa1 = threading.Thread(target = build_lsa, args = (result_112,100, queue1,)) 
thread_lsa2 = threading.Thread(target = build_lsa, args = (result_109,100, queue2, )) 
thread_lsa1.start()
thread_lsa2.start()
thread_lsa1.join()
thread_lsa2.join()
# Out:
# TF-IDF output shape: (1400000, 61992)
# TF-IDF output shape: (1400000, 64140)
# LSA output shape: (1400000, 100)
# Sum of explained variance ratio: 11%
# LSA output shape: (1400000, 100)
# Sum of explained variance ratio: 11%

# %%
tfidf_vec_112, transformed_x_train_112, svd_112, data_svd_112 = queue1.get()
tfidf_vec_109, transformed_x_train_109, svd_109, data_svd_109 = queue2.get()

# %% [markdown]
# # TOPIC MODELING

# %%
#112
topic_weight_112 = data_svd_112[0]
for i,topic in enumerate(topic_weight_112):
  print("Topic ",i," : ",topic*100)
# Out:
# Topic  0  :  11.250548759997052
# Topic  1  :  -2.270108379532807
# Topic  2  :  1.2836155347695708
# Topic  3  :  3.0512311665627325
# Topic  4  :  -0.5684776303952922
# Topic  5  :  6.594577330905739
# Topic  6  :  10.153237804281744
# Topic  7  :  0.9396817652495563
# Topic  8  :  -2.6836812587298535
# Topic  9  :  -1.443936912138875
# Topic  10  :  -3.6111001303271864
# Topic  11  :  6.8622458781693805
# Topic  12  :  2.253741616269288
# Topic  13  :  -1.3904041003969014
# Topic  14  :  -1.0024042526899917
# Topic  75  :  -3.063234420390246
# Topic  76  :  1.1797232163311195
# Topic  77  :  -0.24093458445375251
# Topic  78  :  4.951789098842342
# Topic  79  :  -4.513388415838183
# Topic  80  :  4.337876997898263
# Topic  81  :  0.8980990300411051
# Topic  82  :  2.685639351184677
# Topic  83  :  -1.4336983442285578
# Topic  84  :  0.9576400636960392
# Topic  85  :  -3.462068759629429
# Topic  86  :  1.0587694093722746
# Topic  87  :  -0.2563967865032646
# Topic  88  :  3.6373706730755413
# Topic  89  :  2.386623600454685
# Topic  90  :  0.02012870493542338
# Topic  91  :  1.6160779228697302
# Topic  92  :  0.5065213756402828
# Topic  93  :  -3.5942508207282167
# Topic  94  :  1.2984343127927502
# Topic  95  :  1.075671233548061
# Topic  96  :  -1.355336349156012
# Topic  97  :  2.5314039693498653
# Topic  98  :  -3.1982956943749126
# Topic  99  :  0.6892957279360724

# %%
topic_weight = np.concatenate(topic_weight_112,topic_weight_109)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11536/3753127250.py in <module>
# ----> 1 topic_weight = np.concatenate(topic_weight_112,topic_weight_109)
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# TypeError: only integer scalar arrays can be converted to a scalar index

# %%
vocab_112 = tfidf_vec_112.get_feature_names()
df_topicweight_112 = []
topicname_112 = []
for i, comp in enumerate(svd_112.components_):
    vocab_comp = zip(vocab_112, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    df_topicweight_112.insert(i,np.array(sorted_words)[:,1])
    topicname_112.append(" ".join(np.array(sorted_words)[:,0]))
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# journal available pp doi international ieee springer et american internet
#
# Topic 1:
# ieee conference international th systems information proceedings electrical symposium transactions
#
# Topic 2:
# springer heidelberg berlin pp und ieee der nature netherlands geotechnical
#
# Topic 3:
# de et la al gruyter en lt em du des
#
# Topic 4:
# press university oxford pp oup cambridge nd notes review ieee
#
# Topic 5:
# available internet anon online elsevier lancet bv al news et
#
# Topic 6:
# et al lt disponível em press university oxford clinical zhang
#
# Topic 7:
# american lt em disponível review notes society association mathematical queries
#
# Topic 8:
# lt em disponível lancet elsevier news bv pp vol anon
#
# Topic 9:
# doi lancet review news notes na weekly reactions new queries
#
# Topic 10:
# science notes technology queries doi food engineering oxford springer university
#
# Topic 11:
# science pp technology american elsevier food society et vol al
#
# Topic 12:
# lancet elsevier notes bv news queries american ieee medical journal
#
# Topic 13:
# review international new book faculty peer evaluation literature postpublication historical
#
# Topic 14:
# na weekly reactions news medical wiley international health nature john
#
# Topic 15:
# notes der queries und journal verlag wiley et al für
#
# Topic 16:
# notes wiley queries john society sons inc mathematical international chemistry
#
# Topic 17:
# na reactions weekly society review notes queries pp engineering fluconazole
#
# Topic 18:
# ieee wiley information anon transactions editorial john sons board berlin
#
# Topic 19:
# wiley elsevier american john sons bv editorial inc board international
#
# Topic 20:
# lancet news review society der wiley engineering international und heidelberg
#
# Topic 21:
# anon editorial nd board et international online al dois ii
#
# Topic 22:
# new york news medicine editorial cheminform board springer ieee anthropology
#
# Topic 23:
# editorial board health society ifc ii research internet management kim
#
# Topic 24:
# research new cancer nd anon zhang information wang li analysis
#
# Topic 25:
# research lancet cancer ieee nature society science cheminform america vol
#
# Topic 26:
# nd new society elsevier nature bv index notes queries dois
#
# Topic 27:
# bmj clinical medicine letters doi medical physics pp general health
#
# Topic 28:
# information management nature bmj international springer medical publishing technical new
#
# Topic 29:
# cheminform bmj nd abstract nono synthesis medical clinical informationsdienst chemischer
#
# Topic 30:
# education bmj research analysis clinical medical der engineering study science
#
# Topic 31:
# nature lancet analysis zhang li wang nd medical dois pp
#
# Topic 32:
# health analysis anon mathematical index cheminform author lancet uk volume
#
# Topic 33:
# anon online nature medicine engineering health human doi cheminform oxford
#
# Topic 34:
# cancer education reviews cell medicine technology online mathematical biology nature
#
# Topic 35:
# nature chemistry index medicine physics health chem volume news letters
#
# Topic 36:
# technology bmj nature macmillan palgrave uk der new engineering history
#
# Topic 37:
# verlag kim anon thieme georg health chemistry chem new technology
#
# Topic 38:
# verlag bmj nature engineering thieme georg cancer reviews management human
#
# Topic 39:
# kim engineering nature uk cancer dois limited informa macmillan chemical
#
# Topic 40:
# online reviews bmj management kim book nd lancet social oxford
#
# Topic 41:
# management index cancer social anon volume european reviews pp cell
#
# Topic 42:
# kim bmj conference psychology lee technology anon systems studies index
#
# Topic 43:
# uk management medicine macmillan palgrave studies bmj informa history verlag
#
# Topic 44:
# dois analysis crossref inactive international vol engineering technology american der
#
# Topic 45:
# studies online conference volume index new vol author analysis url
#
# Topic 46:
# dois crossref inactive medicine using study reviews scientific applied vol
#
# Topic 47:
# technology medical research medicine management systems reviews using book mathematical
#
# Topic 48:
# medical kim association zhang new applications institute japan america li
#
# Topic 49:
# physics management dois crossref news letters inactive vol mathematical informa
#
# Topic 50:
# dois crossref reviews inactive news systems online psychology education index
#
# Topic 51:
# chem cancer phys review using systems anon conference control rev
#
# Topic 52:
# sciences index systems volume online information study proceedings academy transactions
#
# Topic 53:
# sciences psychology des limited chem informa proceedings social kim page
#
# Topic 54:
# mathematical nd reviews treatment clinical news vol nature surgery matter
#
# Topic 55:
# news chem medical world clinical social development treatment sciences technology
#
# Topic 56:
# psychology der studies limited informa uk society medical van association
#
# Topic 57:
# systems studies using matter front applied iii health medical social
#
# Topic 58:
# studies sciences encyclopedia chem publishing institute history netherlands index life
#
# Topic 59:
# matter front disease chemistry human des cover current von clinical
#
# Topic 60:
# human using materials american development international physiology von studies applied
#
# Topic 61:
# america informa limited systems uk north clinics institute medicine control
#
# Topic 62:
# human association surgery systems factors publications van proceedings lee press
#
# Topic 63:
# chemistry vol analysis medical sciences comparative physiology conference biochemistry der
#
# Topic 64:
# analysis surgery th water proceedings management effects national conference sciences
#
# Topic 65:
# treatment using technology diabetes molecular water encyclopedia biology wang proceedings
#
# Topic 66:
# water systems world history volume current treatment scientific matter acta
#
# Topic 67:
# development america effect matter ii mathematical north volume front issue
#
# Topic 68:
# des oxford using association clinical human encyclopedia le surgery history
#
# Topic 69:
# mathematical association studies publications treatment biology sage applied comparative vol
#
# Topic 70:
# world chemistry energy sage law scientific des publications water design
#
# Topic 71:
# vol systems publishing human psychology letters ii chemical teaching learning
#
# Topic 72:
# control rev und food phys engineering encyclopedia physical na social
#
# Topic 73:
# und clinical rev applied european social en analysis phys disease
#
# Topic 74:
# vol study history cell analysis diabetes disease communications nd physics
#
# Topic 75:
# association surgery system communications european reviews using encyclopedia power japanese
#
# Topic 76:
# sage publications materials study disease co oxford cancer internet inc
#
# Topic 77:
# control system applied gruyter publications von sage physics energy history
#
# Topic 78:
# study law und history north routledge liu public european publishing
#
# Topic 79:
# public control des food current disease ii opinion diabetes reviews
#
# Topic 80:
# development chemical ii british medical environmental surgery current history rev
#
# Topic 81:
# th power vol energy systems human clinical applied the heat
#
# Topic 82:
# letters design law lee synthesis social methods control method properties
#
# Topic 83:
# food mathematical properties encyclopedia psychology water comparative reactions human environmental
#
# Topic 84:
# history surgery power philosophy effect teaching proceedings letters la safety
#
# Topic 85:
# system philosophy teaching effect gruyter des ii transfer mass encyclopedia
#
# Topic 86:
# chemical chemistry public surgery history learning communications sage wang data
#
# Topic 87:
# diabetes la patients historical type und volume philosophy page chromatography
#
# Topic 88:
# australian design ii study reactions applications proceedings publishing experimental south
#
# Topic 89:
# disease quarterly law british water nursing applied north proceedings environmental
#
# Topic 90:
# molecular world mathematical rev australian biology japan quarterly environment development
#
# Topic 91:
# practice synthesis disease chen college applications european institute sage publications
#
# Topic 92:
# cell vol phys acta rev law encyclopedia lee chemical policy
#
# Topic 93:
# food wiley surgery molecular online acta study processing netherlands electrical
#
# Topic 94:
# molecular water study methods effects applications vol economics public iii
#
# Topic 95:
# philosophy reactions data books water weekly molecular fluconazole internet case
#
# Topic 96:
# effects gruyter conference psychological measurement philosophy law diabetes teaching college
#
# Topic 97:
# food system quarterly design retrieved wiley li acta und bulletin
#
# Topic 98:
# theory methods law state historical care proceedings vol based european
#
# Topic 99:
# lee practice comparative data care environmental ii co computer therapy

# %%
vocab_109 = tfidf_vec_109.get_feature_names()
df_topicweight_109 = []
topicname_109 = []
for i, comp in enumerate(svd_109.components_):
    vocab_comp = zip(vocab_109, comp)
    sorted_words = sorted(vocab_comp, key= lambda x:x[1], reverse=True)[:10]
    print("Topic "+str(i)+": ")
    df_topicweight_109.insert(i,np.array(sorted_words)[:,1])
    topicname_109.append(" ".join(np.array(sorted_words)[:,0]))
    for t in sorted_words:
        print(t[0],end=" ")
    print("\n")
# Out:
# Topic 0:
# journal available international pp ieee doi conference et internet al
#
# Topic 1:
# ieee conference international th systems control symposium information proceedings multimedia
#
# Topic 2:
# press university oxford pp nd springer cambridge berlin heidelberg dictionary
#
# Topic 3:
# journal press university oxford american medical association society cambridge oup
#
# Topic 4:
# springer berlin heidelberg pp nature der encyclopedia science und us
#
# Topic 5:
# available internet al et anon elsevier bv online cheminform wang
#
# Topic 6:
# al et lt em disponível wang zhang li chen cheminform
#
# Topic 7:
# science lt technology em disponível new vol news doi products
#
# Topic 8:
# elsevier doi bv review pp international editorial research board vol
#
# Topic 9:
# lt em disponível available review online anon der und vol
#
# Topic 10:
# doi review und der book health nursing cheminform research von
#
# Topic 11:
# und der verlag für von die cheminform pp elsevier zeitschrift
#
# Topic 12:
# journal em disponível editorial lt doi international springer board applied
#
# Topic 13:
# doi elsevier research nursing bv health der editorial und board
#
# Topic 14:
# cheminform nd american doi engineering society wang lt li abstract
#
# Topic 15:
# doi review american elsevier et al association medical index bv
#
# Topic 16:
# cheminform abstract nono review international medical association synthesis informationsdienst chemischer
#
# Topic 17:
# nd online anon editorial board international journal cheminform ifc abstract
#
# Topic 18:
# wang li review research zhang association medical chen editorial board
#
# Topic 19:
# editorial board ifc research society review cheminform american et al
#
# Topic 20:
# research new nature ieee index studies na society cancer human
#
# Topic 21:
# nature na vol pp reviews bmj editorial book weekly board
#
# Topic 22:
# anon dictionary online reviews oxford benezit artists book berlin heidelberg
#
# Topic 23:
# engineering anon index volume biology wiley author news cell review
#
# Topic 24:
# nd review journal nature ieee na control new science index
#
# Topic 25:
# physics applied al et systems wiley journal materials theory medical
#
# Topic 26:
# na anon index nursing american international physics volume author et
#
# Topic 27:
# nature engineering online elsevier book reviews bv review research international
#
# Topic 28:
# bmj control engineering anon medical practice systems online services reports
#
# Topic 29:
# new nature world information anon technology technical scientific analysis systems
#
# Topic 30:
# na engineering weekly reactions wiley nursing new nd review dictionary
#
# Topic 31:
# reviews engineering book medicine new world cell biology news choice
#
# Topic 32:
# book reviews wiley bmj nd volume research inc john contents
#
# Topic 33:
# bmj new physics dictionary medicine international medical nd benezit artists
#
# Topic 34:
# surgery index japanese association technology chest author society anon japan
#
# Topic 35:
# bmj medicine information systems wiley surgery technical scientific na physics
#
# Topic 36:
# control index dictionary engineering american benezit artists author systems social
#
# Topic 37:
# surgery anon association control japanese news chest research studies international
#
# Topic 38:
# anon systems medicine control information medical biology book theory nd
#
# Topic 39:
# education wiley anon american uk limited informa bmj online technology
#
# Topic 40:
# anon studies technology bmj american applied uk analysis informa limited
#
# Topic 41:
# medicine studies publications anon sage doi methods law medical pp
#
# Topic 42:
# studies news technology medicine uk surgery informa limited notes chemical
#
# Topic 43:
# surgery nursing volume materials matter issue care technology cover proceedings
#
# Topic 44:
# social analysis applied news ieee chem systems practice development publications
#
# Topic 45:
# education materials analysis uk limited informa biology environmental properties law
#
# Topic 46:
# social uk informa limited na materials bmj health weekly international
#
# Topic 47:
# control analysis methods applied development cell technology health biology sae
#
# Topic 48:
# applied medical theory volume medicine issue society matter publications world
#
# Topic 49:
# lee kim control nursing uk informa limited using materials notes
#
# Topic 50:
# nursing systems care cancer uk materials association engineering international japan
#
# Topic 51:
# theory study management notes social human care technology queries der
#
# Topic 52:
# materials lancet education social news information study properties analysis world
#
# Topic 53:
# notes law theory queries lancet practice analysis cancer design zhang
#
# Topic 54:
# development lancet sae nursing technical human wiley physics vol ieee
#
# Topic 55:
# lancet technology engineering education marriages deaths births lee january phys
#
# Topic 56:
# lancet proceedings cell publications conference acm management chem nursing sage
#
# Topic 57:
# analysis lancet technology social physics matter environmental clinical nuclear issue
#
# Topic 58:
# materials law technology japan control properties human lancet social cell
#
# Topic 59:
# der study american medicine van lancet verlag methods testing nature
#
# Topic 60:
# publications der sage data notes nuclear lee queries oxford la
#
# Topic 61:
# evaluation notes lee systems cell faculty news family queries kim
#
# Topic 62:
# world human analysis notes publications control queries technology sage vol
#
# Topic 63:
# law cell environmental wang und disease control publications technology encyclopedia
#
# Topic 64:
# human methods environmental japan notes using evaluation lancet verlag chemistry
#
# Topic 65:
# publications und sage disease study new physics systems li oxford
#
# Topic 66:
# japan world association history development phys institute environmental energy management
#
# Topic 67:
# evaluation publications faculty sage literature theory biomedical phys postpublication peer
#
# Topic 68:
# data clinical development methods für theory zeitschrift zhang cambridge scientific
#
# Topic 69:
# disease education acta japan law social notes letters vol des
#
# Topic 70:
# development data disease japan imaging treatment design acta management institute
#
# Topic 71:
# notes th li methods publishing chem history institute queries contributors
#
# Topic 72:
# using li acta van liu world molecular practice vol system
#
# Topic 73:
# disease chem design ed sciences data int verlag encyclopedia system
#
# Topic 74:
# letters development study clinical america zhang practice north verlag economic
#
# Topic 75:
# des la energy zhang publishing study methods us le vol
#
# Topic 76:
# clinical food chemistry contents safety systems surgery nursing wang lancet
#
# Topic 77:
# methods la disease chemistry study problems social en sae testing
#
# Topic 78:
# north america cell clinics imaging theory vol materials using chem
#
# Topic 79:
# using vol contents study data nursing chemical clinical biology social
#
# Topic 80:
# oxford cell food design sciences methods acta publishing li theory
#
# Topic 81:
# la using contents school li general chemical study proceedings dataset
#
# Topic 82:
# jr clinical parker abstracts la garrity wang japan namesforlife china
#
# Topic 83:
# molecular public acta north effect data america policy dynamics clinics
#
# Topic 84:
# contents cancer publishing development wang letters chemical effect table jr
#
# Topic 85:
# phys disease chen publishing li rev en introduction food van
#
# Topic 86:
# li cells data society practice letters study care wiley nuclear
#
# Topic 87:
# zhang en contents society van vol communications ed cancer molecular
#
# Topic 88:
# treatment disease european sciences modern ii des software jr physical
#
# Topic 89:
# letters politics using zhang iv news language food japan current
#
# Topic 90:
# vol european des sae communications ed systems us films management
#
# Topic 91:
# news contents energy verlag methods phys physical rev sciences encyclopedia
#
# Topic 92:
# food publishing general european sae school safety language wang african
#
# Topic 93:
# history acta using theory sci th imaging food disease case
#
# Topic 94:
# von environmental la food bibliography en theory mechanics african und
#
# Topic 95:
# history letters und design methods music treatment contents education management
#
# Topic 96:
# acm des van food symposium design european blood chemical zhang
#
# Topic 97:
# chen sciences th van des en meeting data ii care
#
# Topic 98:
# chemical vol mathematics letters school sciences publishing concrete med imaging
#
# Topic 99:
# system concrete für editor introduction physics cell century cambridge african

# %%
df_topicweight = pd.DataFrame(df_topicweight_112 + df_topicweight_109)
df_topicweight
# Out:
#                        0                    1                    2  \
# 0     0.3401731943361585   0.2487446635324347   0.2423427715625682
# 1     0.6045617918036749  0.34230455472031907  0.28069959578690057
# 2    0.48469726846327343   0.3735810036144499   0.3694288716923411
# 3     0.7787753012725103  0.21741621300465486  0.16679440848997767
# 4     0.5054025065580967  0.46744891833154667  0.31599986582668865
# ..                   ...                  ...                  ...
# 195  0.20335604276134533  0.20019702466752184  0.17081331344137166
# 196  0.14961083072695447   0.1338269172361029  0.11920580652611466
# 197  0.11844279665252677  0.11208059259212541  0.10883491941138375
# 198  0.20125619566073488   0.1523701084133596  0.13903106372764654
# 199   0.1585798056681002  0.15201613072261996   0.1254310424285283
#
#                        3                    4                    5  \
# 0    0.20724291724907373  0.19594473884861796  0.19186046579147997
# 1    0.14979479783955513   0.1000700253409622   0.0988835716477108
# 2     0.2813120568069355  0.10661806405106276  0.09403013045263293
# 3     0.1479974261563206  0.13856105670714228  0.11442498697095184
# 4    0.15409941441573774  0.12897669940705303  0.10930714321404411
# ..                   ...                  ...                  ...
# 195   0.1460998572262442  0.12056498305186922  0.11176744870313782
# 196  0.11801505430788867  0.10826510574716745  0.10119570022947544
# 197  0.10790808748627052  0.08709519039252546  0.08149724620416697
# 198   0.1216904974341518  0.11939420756761522  0.11507714533672116
# 199  0.09079719710296942  0.08842445063249535  0.08521294113012177
#
#                        6                    7                    8  \
# 0     0.1674131454893266  0.15239469130826092  0.15215414139368932
# 1    0.08275263351830817  0.08151240097445496  0.07981155591085606
# 2    0.07548460859923185  0.06695502056544164  0.05899194905238043
# 3    0.08137847478223798  0.08098090877099327   0.0795018611459372
# 4    0.09010871852496688  0.08836794854144274  0.07954124464573462
# ..                   ...                  ...                  ...
# 195  0.10180198373075175  0.09786425351584135  0.09430618070781646
# 196   0.0924476903411475  0.09194993505712487   0.0875548946809756
# 197  0.08023668529921905  0.07605956970285631  0.07477255392031934
# 198  0.10774670261849001  0.10219850712107457  0.09302577537458212
# 199  0.08273061570770056  0.07904410522550644    0.077961887396564
#
#                         9
# 0     0.14892174429971575
# 1     0.07971713927076361
# 2    0.056360852221754985
# 3     0.07545265973793049
# 4     0.07873851294018376
# ..                    ...
# 195   0.08820258564877348
# 196   0.08078697036924525
# 197   0.07324184128712982
# 198   0.08618249015083992
# 199     0.077357701815285
#
# [200 rows x 10 columns]

# %%
topicweight = df_topicweight_112 + df_topicweight_109

# %%
list_app_name = list(topicname_109 + topicname_112)

dic_recommended_1 = {}

for index in range(df_topicweight.shape[0]):

    similarities_1 = linear_kernel(topicweight[index].reshape(1, -1) ,topicweight).flatten()
    related_docs_indices_1 = (-similarities_1).argsort()[:10]

    dic_recommended_1.update({list_app_name[index]:[list_app_name[i] for i in related_docs_indices_1]})

df_content_based_results_1 = pd.DataFrame(dic_recommended_1)
df_content_based_results_1.reset_index(inplace=True)
df_content_based_results_1 = df_content_based_results_1.T
df_content_based_results_1
# Out:
#                                                                                                     0  \
# index                                                                                               0
# journal available international pp ieee doi con...  elsevier doi bv review pp international editor...
# ieee conference international th systems contro...  journal press university oxford american medic...
# press university oxford pp nd springer cambridg...  press university oxford pp nd springer cambrid...
# journal press university oxford american medica...  journal press university oxford american medic...
# ...                                                                                               ...
# philosophy reactions data books water weekly mo...